# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

# %% [markdown]
# # Mobiligrams

# %%
files = {
    "CAR7 — m/z 340.1755":  '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/mobiligrams/mobiligram_CAR7_MZ_340_1755_RT_4_3.tsv',
    "P4_A2 — m/z 340.1755": '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/mobiligrams/mobiligram_P4_A2_MZ_340_1755_RT_4_3.tsv',
    "CAR7-4 — m/z 420.1323":  '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/mobiligrams/mobiligram_CAR7-4_MZ_420_1323_RT_4_3.tsv',
    "P4_A2 — m/z 420.1323": '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/mobiligrams/mobiligram_P4_A2_MZ_420_1323_RT_4_3.tsv',
}

colors = ["steelblue", "tomato", "seagreen", "darkorchid"]

fig, axes = plt.subplots(4, 1, figsize=(6, 10), sharex=True)

for ax, (label, path), color in zip(axes, files.items(), colors):
    df = pd.read_csv(path, sep="\t")
    ax.plot(df["Mobility"], df["Intensity"], color=color, linewidth=1.2)
    ax.set_title(label, fontsize=11)
    ax.set_ylabel("Intensity", fontsize=10)
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

axes[-1].set_xlabel("Mobility", fontsize=12)
axes[-1].set_xlim(0.6, 1.2)

plt.tight_layout()
plt.savefig('/.../mobiligrams.pdf')
plt.show()

# %% [markdown]
# # QE - HILIC

# %%
files = {
    "CAR7 — m/z 340.1755":  '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/HILIC_LC_QE/CAR7-4_hilic_340_1755.csv',
    "P4_A2 — m/z 340.1755": '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/HILIC_LC_QE/P4_A2_hilic_340_1755.csv',
    "CAR7-4 — m/z 420.1323":  '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/HILIC_LC_QE/CAR7-4_hilic_420_1323.csv',
    "P4_A2 — m/z 420.1323": '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/HILIC_LC_QE/P4_A2_hilic_420_1323.csv',
}

colors = ["steelblue", "tomato", "seagreen", "darkorchid"]

fig, axes = plt.subplots(4, 1, figsize=(6, 10), sharex=True)

for ax, (label, path), color in zip(axes, files.items(), colors):
    df = pd.read_csv(path, sep=",", skiprows=3)
    ax.plot(df["Time(min)"], df["Relative Abundance"], color=color, linewidth=1.2)
    ax.set_title(label, fontsize=11)
    ax.set_ylabel("Intensity", fontsize=10)
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

axes[-1].set_xlabel("Time (min)", fontsize=12)
axes[-1].set_xlim(2.5, 3.6)

plt.tight_layout()
plt.savefig('/.../QE_HILIC.pdf')
plt.show()

# %% [markdown]
# # QE - RP

# %%
files = {
    "CAR7 — m/z 340.1755":  '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/RP_QE/CAR7_RP_340_1755.csv',
    "P4_A2 — m/z 340.1755": '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/RP_QE/P4_A2_RP_340_1755.csv',
    "CAR7-4 — m/z 420.1323":  '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/RP_QE/CAR7-4_RP_420_1323.csv',
    "P4_A2 — m/z 420.1323": '/Users/helenarusso/Documents/Pesquisa/UCSD Post-doc/Carnitines/2025/Synthesis/Retention time matching/Final_files_figure/RP_QE/P4_A2_RP_420_1323.csv',
}

colors = ["steelblue", "tomato", "seagreen", "darkorchid"]

fig, axes = plt.subplots(4, 1, figsize=(6, 10), sharex=True)

for ax, (label, path), color in zip(axes, files.items(), colors):
    df = pd.read_csv(path, sep=",", skiprows=3)
    ax.plot(df["Time(min)"], df["Relative Abundance"], color=color, linewidth=1.2)
    ax.set_title(label, fontsize=11)
    ax.set_ylabel("Intensity", fontsize=10)
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

axes[-1].set_xlabel("Time (min)", fontsize=12)
axes[-1].set_xlim(2.0, 3.4)

plt.tight_layout()
plt.savefig('/.../RP_QE.pdf')
plt.show()
